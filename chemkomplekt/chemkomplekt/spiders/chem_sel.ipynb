# %%
import pandas as pd

# %%
df = pd.read_csv(r'U:\SNABIO\chemkomplekt\chemkomplekt\chem_sel.csv')

# %%
df
# Out:
#                                                  title  \
# 0                        Аммоний вольфрамовокислый чда
# 1                                         Фенолфталеин
# 2                   Железо (II) сернокислое 9-водное ч
# 3                                   Кислота борная  хч
# 4                                    Формалин тех. в/с
# ..                                                 ...
# 736                                Кислота хлорная  хч
# 737                         Калий двухромовокислый чда
# 738                                  Кислота бензойная
# 739  Бутилацетат чда (Бутиловый эфир уксусной кислоты)
# 740                  Барий хромовокислый, хромат бария
#
#                                               category     country   price
# 0                                                  NaN     порошок  2 300
# 1                                 селективные реактивы         NaN  3 500
# 2                                 селективные реактивы         NaN    290
# ...

# %%
df_filled = df.fillna('')  # Fill NaN values with empty strings

# %%
df_filled
# Out:
#                                                  title  \
# 0                        Аммоний вольфрамовокислый чда
# 1                                         Фенолфталеин
# 2                   Железо (II) сернокислое 9-водное ч
# 3                                   Кислота борная  хч
# 4                                    Формалин тех. в/с
# ..                                                 ...
# 736                                Кислота хлорная  хч
# 737                         Калий двухромовокислый чда
# 738                                  Кислота бензойная
# 739  Бутилацетат чда (Бутиловый эфир уксусной кислоты)
# 740                  Барий хромовокислый, хромат бария
#
#                                               category     country   price
# 0                                                          порошок  2 300
# 1                                 селективные реактивы              3 500
# 2                                 селективные реактивы                290
# ...

# %%
df.to_excel('chem_sel.xlsx')

# %%
df_1 = pd.read_excel(r'U:\SNABIO\chemkomplekt\chemkomplekt\spiders\chem_sel.xlsx')

# %%
df_1
# Out:
#      Unnamed: 0                                              title  \
# 0             0                      Аммоний вольфрамовокислый чда
# 1             1                                       Фенолфталеин
# 2             2                 Железо (II) сернокислое 9-водное ч
# 3             3                                 Кислота борная  хч
# 4             4                                  Формалин тех. в/с
# ..          ...                                                ...
# 736         736                                Кислота хлорная  хч
# 737         737                         Калий двухромовокислый чда
# 738         738                                  Кислота бензойная
# 739         739  Бутилацетат чда (Бутиловый эфир уксусной кислоты)
# 740         740                  Барий хромовокислый, хромат бария
#
#                                               category     country   price
# 0                                                  NaN     порошок  2 300
# ...

# %%
data = {'column_name': ['category', 'name']}

# %%
df_3 = pd.DataFrame(data)

# %%
counts = df['category'].value_counts()

# %%
print(counts)
# Out:
# category
# селективные реактивы                                                                                                                  484
# необратимый                                                                                                                             3
# нет                                                                                                                                     2
# Порошок                                                                                                                                 1
#                                                                                                                                         1
# зеленый                                                                                                                                 1
# да                                                                                                                                      1
# ...

# %%
counts = df['name'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File U:\SNABIO\venv_laptop\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 counts = df['name'].value_counts()
#
# ...

# %%
print(counts)
# Out:
# category
# селективные реактивы                                                                                                                  484
# необратимый                                                                                                                             3
# нет                                                                                                                                     2
# Порошок                                                                                                                                 1
#                                                                                                                                         1
# зеленый                                                                                                                                 1
# да                                                                                                                                      1
# ...
