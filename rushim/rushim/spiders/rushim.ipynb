# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\bitse\YandexDisk\Rushim\rushim\w_3.csv')

# %%
df
# Out:
#                                       product               category price  \
# 0            Изопропиловый спирт (Пропанол-2)  Реактивы и хим. сырье  4260
# 1    Калий фосфорнокислый 2-замещенный 3 водн  Реактивы и хим. сырье   NaN
# 2                     Натрий салициловокислый  Реактивы и хим. сырье   NaN
# 3                   Крахмал текстильный Aprin  Реактивы и хим. сырье   110
# 4                     Крахмал водорастворимый  Реактивы и хим. сырье   798
# ..                                        ...                    ...   ...
# 794                             Бензилбензоат  Реактивы и хим. сырье   570
# 795                           Дифениламин имп  Реактивы и хим. сырье  2900
# 796     Бентонит (глинопорошок для виноделия)  Реактивы и хим. сырье  1985
# 797                            Калий дихромат  Реактивы и хим. сырье   NaN
# 798                       Уранин А (индикатор  Реактивы и хим. сырье   NaN
#
# ...

# %%
df_him = df

# %%
#df_him.to_excel('result-rushim.xlsx', index=False)

# %%
df_1 = pd.read_excel(r'C:\Users\bitse\Desktop\result_rushim_pandas.xlsx')

# %%
dup = df_1.drop_duplicates(subset=['product'])

# %%
dup
# Out:
#                                       product               category  price  \
# 0            Изопропиловый спирт (Пропанол-2)  Реактивы и хим. сырье    NaN
# 1    Калий фосфорнокислый 2-замещенный 3 водн  Реактивы и хим. сырье    NaN
# 2                     Натрий салициловокислый  Реактивы и хим. сырье    NaN
# 3                   Крахмал текстильный Aprin  Реактивы и хим. сырье    NaN
# 4                     Крахмал водорастворимый  Реактивы и хим. сырье    NaN
# ..                                        ...                    ...    ...
# 789                          Трипановый синий  Реактивы и хим. сырье    NaN
# 790                    Калий сернокислый пиро  Реактивы и хим. сырье    NaN
# 791                         Изоамиловый спирт  Реактивы и хим. сырье    NaN
# 792             Натрий селенистокислый кислый  Реактивы и хим. сырье    NaN
# 798                       Уранин А (индикатор  Реактивы и хим. сырье    NaN
#
# ...

# %%
dup.to_excel('result_pandas______123.xlsx')
