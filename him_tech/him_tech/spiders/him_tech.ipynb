# %%
import pandas as pd

# %%
df = pd.read_csv(r'U:\SNABIO\him_tech\himtech.csv')

# %%
df
# Out:
#        category                                  name  price
# 0    Флокулянты               Флокулянт Praestol 2530    350
# 1    Флокулянты           Флокулянт Superfloc A120PWG    350
# 2    Флокулянты           Флокулянт Superfloc A120HMW    350
# 3    Флокулянты              Флокулянт Superfloc A120    350
# 4    Флокулянты           Флокулянт Superfloc A110PWG    350
# ..          ...                                   ...    ...
# 589  Флокулянты           Флокулянт SPECFLOK A7926-10      0
# 590  Флокулянты               Флокулянт Praestol 2505    350
# 591  Флокулянты            Флокулянт Flopam AN 956 SH    350
# 592  Флокулянты               Флокулянт Praestol 2515    350
# 593  Флокулянты  Флокулянт Magnafloc (Магнафлок) 10-A    350
#
# [594 rows x 3 columns]

# %%
df.to_excel('him_tech.xlsx')

# %%
df_1 = pd.read_excel(r'U:\SNABIO\him_tech\him_tech\spiders\him_tech.xlsx')

# %%
df_1
# Out:
#      Unnamed: 0    category                                  name  price
# 0             0  Флокулянты               Флокулянт Praestol 2530    350
# 1             1  Флокулянты           Флокулянт Superfloc A120PWG    350
# 2             2  Флокулянты           Флокулянт Superfloc A120HMW    350
# 3             3  Флокулянты              Флокулянт Superfloc A120    350
# 4             4  Флокулянты           Флокулянт Superfloc A110PWG    350
# ..          ...         ...                                   ...    ...
# 589         589  Флокулянты           Флокулянт SPECFLOK A7926-10      0
# 590         590  Флокулянты               Флокулянт Praestol 2505    350
# 591         591  Флокулянты            Флокулянт Flopam AN 956 SH    350
# 592         592  Флокулянты               Флокулянт Praestol 2515    350
# 593         593  Флокулянты  Флокулянт Magnafloc (Магнафлок) 10-A    350
#
# [594 rows x 4 columns]

# %%
data = {'column_name': ['category', 'name']}

# %%
df_3 = pd.DataFrame(data)

# %%
counts = df['category'].value_counts()

# %%
print(counts)
# Out:
# category
# Флокулянты                             100
# Техническая химия                      100
# Активированные угли                    100
# Ионообменные смолы                     100
# Ингибиторы коррозии и солеотложения     62
# Силикагели                              42
# Цеолиты                                 41
# Коагулянты                              32
# Кварцевый песок                         17
# Name: count, dtype: int64

# %%
counts = df['name'].value_counts()

# %%
print(counts)
# Out:
# name
# Флокулянт Praestol 2530                 1
# Флокулянт Superfloc A120PWG             1
# Флокулянт Superfloc A120HMW             1
# Флокулянт Superfloc A120                1
# Флокулянт Superfloc A110PWG             1
#                                        ..
# Флокулянт SPECFLOK A7926-10             1
# Флокулянт Praestol 2505                 1
# Флокулянт Flopam AN 956 SH              1
# Флокулянт Praestol 2515                 1
# Флокулянт Magnafloc (Магнафлок) 10-A    1
# Name: count, Length: 594, dtype: int64
